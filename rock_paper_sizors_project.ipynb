# %%
import random

#getting values

    # ask the user if he or she wants rock - 1, papper - 2 or sizors -3
    
number = int(input("What do you choose? Type 1 for Rock, 2 for Paper or 3 for sizors "))

    # setting and displaying values    

        # if user choice 1 - rock


        
def display_set(number):
    if number == 1:

    # print value

        print(

                '''
                       _______
                    ---'   ____)
                          (_____)
                          (_____)
                          (____)
                    ---.__(___)

                ''' )

                # set value = 3

        value = 0
        
        return value


    # if user choice 2 - papper

    if number == 2:

        # print value

        print(

                '''
                    _______
                ---'   ____)____
                          ______)
                          _______)
                         _______)
                ---.__________)

                ''' )

                # set papper = 4

        value = 1
        
        return value

            # if user choice 3 - sizors

    if number == 3:

            # print value

            print(

            '''
                  _______
                ---'   ____)____
                          ______)
                       __________)
                      (____)
                ---.__(___)


                 ''' )


                # set sizors = 5

            value = 2
            
            return value
        
value1 = display_set(number)

    # generate a random number for the bot

number2 = random.uniform(0, 10)

def automatic_display_set(number2):

    
    if number2 <= 3.333:

    # print value

        print(

                '''
                       _______
                    ---'   ____)
                          (_____)
                          (_____)
                          (____)
                    ---.__(___)

                ''' )

                # set value = 3

        value = 0
        
        return value


    # if number is between 3.333 - 6.666 - papper

    if number2 >= 3.333 and number2 <= 6.666 :

        # print value

        print(

                '''
                    _______
                ---'   ____)____
                          ______)
                          _______)
                         _______)
                ---.__________)

                ''' )

                # set papper = 4

        value = 1
        
        return value

   # if number is between 6.666 - 10 - sizors

    if number2 >= 6.666 and number2 <= 10 :

            # print value

            print(

            '''
                  _______
                ---'   ____)____
                          ______)
                       __________)
                      (____)
                ---.__(___)


                 ''' )


                # set sizors = 5

            value = 2
            
            return value


value2 = automatic_display_set(number2) 

        
# calculations 


    # if value1 == value2 = value 1
def evaluation(value1, value2):    
    if value1 == value2:
        return "        TIE          "

            # print tie

        # if value1 - value1 == - 1

    elif value1 < value2:
        if value1 == 2 or value1 == 1 :
            return "     You loose    "

    elif value1 - value2 == 2:
        return "     You loose    "

        # print you lose
    elif value1 + value2 == 1 or value1 - value2 == 1 :
        return "      You win    "

           # else 

        # print you win

         # if number is betwee
            
         

print(evaluation(value1, value2))
# Out:
# What do you choose? Type 1 for Rock, 2 for Paper or 3 for sizors 3
#
#                   _______
#                 ---'   ____)____
#                           ______)
#                        __________)
#                       (____)
#                 ---.__(___)
#
#
#
#
#                     _______
#                 ---'   ____)____
#                           ______)
#                           _______)
#                          _______)
#                 ---.__________)
#
#
#       You win

# %%
# Out:
# [[2, 's'],
#  [3, 's'],
#  [1, 'u'],
#  [1, 'u'],
#  [1, 'p'],
#  [1, 'p'],
#  [1, 'p'],
#  [1, 'p'],
#  [1, 'p'],
#  [1, 'p'],
#  [1, 'p'],
#  [1, 'p']]

# %%
array = [[0,1]]

array[0][1]
# Out:
# 1
